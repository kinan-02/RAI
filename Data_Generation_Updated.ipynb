# %%
import pandas as pd
import numpy as np

doctors = pd.DataFrame(index=np.arange(1,1001))

# %%
#the feedbacks are sorted from worst to best. len == 100
feedbacks = [
  "Doctor was rude and dismissive, worst experience ever.",
  "Barely listened to my concerns, very disappointed.",
  "Unhelpful and unfriendly, won't return.",
  "Lacked empathy and bedside manner.",
  "Seemed rushed, didn't answer my questions.",
  "Doctor was cold and unapproachable.",
  "Didn't seem to care about my pain.",
  "Hard to communicate with, not understanding.",
  "More interested in paperwork than patients.",
  "Unpleasant attitude, felt ignored.",
  "Brief and uninterested in my symptoms.",
  "Clinical skills good, but no personal touch.",
  "Average care, but lacked warmth.",
  "Competent but impersonal, not satisfied.",
  "Decent doctor, but could be friendlier.",
  "Professional but not very engaging.",
  "Efficient but somewhat detached.",
  "Knowledgeable but not very personable.",
  "Quick service, but lacked empathy.",
  "Professional, but needs better communication.",
  "Good care, but could improve friendliness.",
  "Met expectations, but not outstanding.",
  "Average experience, nothing special.",
  "Routine check-up, no issues.",
  "Standard care, no complaints.",
  "Competent and straightforward.",
  "Satisfactory visit, met my needs.",
  "Solid care, efficient service.",
  "Friendly but busy, still helpful.",
  "Approachable and knowledgeable.",
  "Helpful and attentive doctor.",
  "Kind and professional.",
  "Caring and efficient.",
  "Listened well and provided good care.",
  "Empathetic and thorough.",
  "Friendly and knowledgeable.",
  "Made me feel comfortable.",
  "Excellent communication skills.",
  "Very attentive and caring.",
  "Reassuring and kind.",
  "Went above and beyond.",
  "Outstanding bedside manner.",
  "Extremely knowledgeable and caring.",
  "Highly professional and kind.",
  "Always makes time for questions.",
  "Wonderful doctor, very attentive.",
  "Truly cares about patients.",
  "Exceptional service and care.",
  "Best doctor I've ever had.",
  "Absolutely amazing, can't recommend enough.",
  "Fantastic care, highly recommend.",
  "Incredibly attentive and compassionate.",
  "Top-notch service, very professional.",
  "Goes the extra mile for patients.",
  "Always listens and provides excellent care.",
  "Wonderful experience, very satisfied.",
  "Extremely patient and understanding.",
  "The best in the field.",
  "Highly skilled and compassionate.",
  "Always kind and helpful.",
  "Makes you feel at ease.",
  "Genuine care and concern for patients.",
  "Amazing doctor, very thorough.",
  "Exceptional at explaining things clearly.",
  "Highly recommend, very professional.",
  "Always goes above and beyond.",
  "Fantastic bedside manner.",
  "Extremely knowledgeable and friendly.",
  "Superb care, very attentive.",
  "Remarkably kind and skilled.",
  "Always puts patients first.",
  "Outstanding in every way.",
  "Remarkable service, highly recommend.",
  "Top-tier medical care.",
  "Always professional and caring.",
  "Expert care, very satisfied.",
  "Very thorough and attentive.",
  "Great listener, very compassionate.",
  "Consistently excellent care.",
  "Highly professional and knowledgeable.",
  "Wonderful and caring doctor.",
  "Always explains things clearly.",
  "Excellent service, highly recommend.",
  "The best doctor I've seen.",
  "Very empathetic and skilled.",
  "Extremely professional and kind.",
  "Exceptional in every aspect.",
  "Always makes you feel comfortable.",
  "Top-notch care and service.",
  "Absolutely fantastic experience.",
  "Highly attentive and knowledgeable.",
  "Consistently outstanding care.",
  "Remarkably empathetic and thorough.",
  "Always provides excellent care.",
  "Fantastic in every way.",
  "The best medical experience.",
  "Highly skilled and caring.",
  "Absolutely wonderful doctor.",
  "Incredibly kind and professional.",
  "Always exceeds expectations.",
  "Top-notch in every way.",
  "Absolutely the best care."
]

# %%
import pandas as pd
import random

# Define text samples with multiple examples
patient_feedback_samples = {
    1: ["The surgery was a disaster. The doctor was rude and unprofessional, and the staff were not helpful at all.",
        "Terrible experience. The doctor was dismissive and the procedure went wrong.",
        "I am very disappointed. The surgery was botched and the aftercare was awful.",
        "The surgery was a nightmare. I would never recommend this doctor.",
        "Unprofessional conduct and poor results. Completely dissatisfied.",
        "Worst experience ever. The doctor made several mistakes.",
        "The procedure was a disaster, and I felt very unsafe.",
        "Extremely dissatisfied with the entire process.",
        "The doctor was unprofessional and the surgery failed.",
        "Horrible experience, the surgery left me in worse condition.",
        "The surgery was poorly done, and I had complications.",
        "I felt ignored and mistreated throughout the process.",
        "The surgery left me in more pain than before.",
        "The doctor was arrogant and dismissive of my concerns.",
        "I would never go back to this doctor again.",
        "The worst medical experience I've ever had.",
        "The doctor showed no empathy and was very rough.",
        "The procedure was rushed and poorly executed.",
        "I had a terrible reaction and the doctor was unhelpful.",
        "The doctor made serious errors during the surgery.",
        "I felt neglected and the aftercare was nonexistent.",
        "I experienced severe complications due to the surgery.",
        "The doctor was highly unprofessional and rude.",
        "The entire experience was a complete failure.",
        "The doctor ignored my symptoms and concerns.",
        "The procedure was botched and caused additional issues.",
        "The doctor's attitude was dismissive and uncaring.",
        "The surgery was not successful and I had to seek further treatment.",
        "The doctor was incompetent and the results were disastrous.",
        "I would strongly advise against seeing this doctor."],
    2: ["The procedure didn't go well. I felt neglected, and the recovery has been difficult.",
        "Not happy with the results. The doctor didn't seem to care much.",
        "The surgery was below expectations. The follow-up was poor.",
        "Disappointed with the procedure and the lack of care.",
        "The doctor was indifferent and the surgery wasn't successful.",
        "Not satisfied with the experience. The doctor was inattentive.",
        "The surgery had complications and the doctor was not helpful.",
        "The care provided was inadequate. Recovery has been tough.",
        "The procedure didn't meet my expectations. Felt neglected.",
        "Overall, a negative experience with poor results.",
        "The doctor seemed uninterested in my recovery.",
        "The surgery had more complications than expected.",
        "I felt like just another number, not a patient.",
        "The doctor's bedside manner was lacking.",
        "The results were not what I hoped for.",
        "The procedure was more painful than explained.",
        "I had issues during recovery that were not addressed.",
        "The doctor was not as attentive as I would have liked.",
        "The surgery was less successful than expected.",
        "The doctor's instructions were unclear.",
        "I felt uneasy about the whole process.",
        "The surgery was okay but the recovery was tough.",
        "The doctor did not provide sufficient information.",
        "The care after the surgery was minimal.",
        "I had to follow up multiple times to get answers.",
        "The procedure was not as smooth as promised.",
        "The doctor was somewhat detached and uninterested.",
        "There were some complications that weren't handled well.",
        "The experience left me feeling uncertain.",
        "The surgery was more complicated than it needed to be."],
    3: ["The surgery was okay. The experience was neither good nor bad, just average.",
        "An average experience. The surgery went as expected.",
        "The procedure was fine, nothing remarkable but acceptable.",
        "The surgery was as expected. No major issues.",
        "A standard experience. The doctor did their job.",
        "The surgery was routine and recovery was average.",
        "Neither happy nor unhappy with the surgery. It was okay.",
        "The procedure went as planned. An average experience.",
        "The surgery was fine, not great but not terrible either.",
        "An unremarkable experience. The surgery went as expected.",
        "The doctor did an adequate job. Nothing special.",
        "The procedure was performed competently.",
        "The surgery went as planned, no surprises.",
        "A typical surgical experience, nothing outstanding.",
        "The care was sufficient but not exceptional.",
        "The results were as expected, no complaints.",
        "The doctor was professional, but the experience was average.",
        "The surgery was successful, but the overall experience was average.",
        "The recovery was standard, no major issues.",
        "I received competent care, nothing more.",
        "The procedure met my expectations.",
        "The surgery was performed adequately.",
        "The doctor's care was satisfactory.",
        "The overall experience was neutral.",
        "The surgery was executed as expected.",
        "The care provided was acceptable.",
        "I received adequate care and attention.",
        "The procedure was handled competently.",
        "The overall experience was just fine.",
        "The surgery was routine and went as planned."],
    4: ["The surgery went well, and the doctor was attentive. I'm pleased with the overall outcome.",
        "Good experience. The doctor was caring and professional.",
        "The procedure was successful and the doctor was very attentive.",
        "Satisfied with the surgery and the care provided.",
        "The doctor did a good job and I am happy with the results.",
        "The surgery was well done and the follow-up was great.",
        "A positive experience with a competent doctor.",
        "The procedure went smoothly and I felt well cared for.",
        "Happy with the surgery and the doctor's professionalism.",
        "The doctor was attentive and the surgery was a success.",
        "The doctor provided excellent care and the surgery went well.",
        "I felt confident in the doctor's abilities. Good outcome.",
        "The surgery was successful and the care was attentive.",
        "The procedure was performed with great care.",
        "The doctor was thorough and professional. Satisfied with the results.",
        "I am pleased with the surgery and the aftercare.",
        "The experience was positive and the surgery successful.",
        "The doctor was knowledgeable and the procedure went well.",
        "The surgery was handled expertly and the care was excellent.",
        "The doctor was caring and the surgery a success.",
        "I am satisfied with the results of the surgery.",
        "The procedure was successful and the doctor was attentive.",
        "I had a positive experience and the surgery went well.",
        "The doctor was professional and the care was good.",
        "The surgery was a success and the follow-up care was great.",
        "The doctor did a great job and I am happy with the results.",
        "A very positive surgical experience.",
        "The care I received was excellent and the surgery went well.",
        "The procedure was smooth and the doctor was caring.",
        "I am happy with the outcome of the surgery and the care provided."],
    5: ["Fantastic experience! The doctor was highly professional, and the surgery was a great success. The care I received was top-notch.",
        "Excellent care and results. The doctor was outstanding.",
        "Couldn't be happier with the surgery and the follow-up care.",
        "The doctor was amazing. The surgery was perfect and the recovery was smooth.",
        "The best medical experience I've ever had. Highly recommend.",
        "The surgery exceeded my expectations. The doctor was fantastic.",
        "Top-quality care and excellent surgical results.",
        "The doctor was incredibly skilled and the surgery went perfectly.",
        "I received exceptional care and the surgery was a success.",
        "Outstanding experience from start to finish.",
        "The doctor was superb and the surgery went flawlessly.",
        "I couldn't have asked for a better experience.",
        "The surgery was perfect and the doctor was highly skilled.",
        "The care provided was exceptional and the surgery was successful.",
        "The doctor was highly professional and the results were excellent.",
        "A flawless experience with outstanding results.",
        "I am extremely satisfied with the surgery and the care provided.",
        "The doctor was excellent and the surgery was a success.",
        "The best surgical experience I've had.",
        "The doctor was amazing and the surgery was perfect.",
        "Highly recommend this doctor for their excellent care.",
        "The surgery went perfectly and the follow-up care was great.",
        "Couldn't be happier with the results and the care provided.",
        "The doctor was exceptional and the surgery was a success.",
        "Outstanding care and perfect surgical results.",
        "The doctor was incredibly skilled and the experience was fantastic.",
        "The surgery exceeded all my expectations.",
        "The best care I've ever received. The surgery was perfect.",
        "I am extremely happy with the surgery and the care provided.",
        "The doctor was fantastic and the results were excellent."]
}

# %%
recommendation_letters_samples = {
    1: ["I cannot recommend this surgeon. There have been multiple issues with performance and professionalism.",
        "This surgeon has shown consistent lack of professionalism and skill.",
        "The surgeon's performance has been below acceptable standards.",
        "Multiple complaints from patients about this surgeon.",
        "The surgeon lacks the necessary skills for this role.",
        "There have been significant issues with this surgeon's work.",
        "This surgeon's conduct has been highly problematic.",
        "The surgeon's skills and professionalism are seriously lacking.",
        "I strongly advise against hiring this surgeon.",
        "This surgeon has failed to meet basic professional standards.",
        "The surgeon's work has been subpar and concerning.",
        "There are major issues with this surgeon's practice.",
        "The surgeon has received numerous negative reviews.",
        "I cannot endorse this surgeon's work.",
        "The surgeon's behavior and skills are not up to par.",
        "There have been too many problems with this surgeon.",
        "The surgeon's approach to patient care is inadequate.",
        "I have serious reservations about this surgeon.",
        "The surgeon has not demonstrated the required competencies.",
        "This surgeon has been a source of multiple complaints.",
        "I would not recommend this surgeon for any position.",
        "The surgeon's work ethic and skills are questionable.",
        "The surgeon has consistently underperformed.",
        "The surgeon's professional conduct is highly concerning.",
        "The surgeon has made several critical mistakes.",
        "I strongly discourage hiring this surgeon.",
        "The surgeon's overall performance is unacceptable.",
        "The surgeon has not met the necessary professional standards.",
        "The surgeon's work has been fraught with issues.",
        "There are serious concerns about this surgeon's abilities."],
    2: ["There have been some concerns regarding this surgeon's skills and attitude. I would suggest caution.",
        "This surgeon has had several performance issues.",
        "The surgeon's work has been somewhat inconsistent.",
        "There have been a few complaints about this surgeon.",
        "I have some reservations about this surgeon's abilities.",
        "The surgeon's performance has been mixed.",
        "There have been occasional issues with this surgeon's work.",
        "The surgeon's attitude and skills are sometimes lacking.",
        "I would advise caution in hiring this surgeon.",
        "The surgeon's work has been satisfactory but with some concerns.",
        "The surgeon has had a few problems in the past.",
        "There have been some negative reviews about this surgeon.",
        "The surgeon's approach is sometimes problematic.",
        "I have some doubts about this surgeon's professionalism.",
        "The surgeon's performance needs improvement.",
        "There have been a few incidents involving this surgeon.",
        "The surgeon's skills are sometimes inadequate.",
        "There have been minor issues with this surgeon's work.",
        "The surgeon has shown some unprofessional behavior.",
        "I would recommend careful consideration before hiring this surgeon.",
        "The surgeon's track record is not entirely positive.",
        "There have been occasional lapses in this surgeon's performance.",
        "The surgeon's conduct has raised some concerns.",
        "I would suggest a probationary period for this surgeon.",
        "The surgeon's work is sometimes below expectations.",
        "There have been sporadic complaints about this surgeon.",
        "The surgeon's performance is inconsistent.",
        "There are some areas where this surgeon needs to improve.",
        "I have some concerns about this surgeon's competence.",
        "The surgeon's work has been satisfactory but with notable issues."],
    3: ["This surgeon has performed adequately. There are no major concerns, but also no standout qualities.",
        "The surgeon's work has been satisfactory and meets basic standards.",
        "The surgeon has performed at an acceptable level.",
        "There are no significant issues with this surgeon's performance.",
        "The surgeon's work is competent but unremarkable.",
        "The surgeon meets the necessary requirements.",
        "The surgeon's performance is average and meets expectations.",
        "The surgeon has shown satisfactory skills.",
        "The surgeon's work is sufficient and meets basic standards.",
        "The surgeon performs adequately under normal conditions.",
        "The surgeon's work is generally satisfactory.",
        "The surgeon meets the expected professional standards.",
        "The surgeon's performance is acceptable.",
        "The surgeon has consistently met basic expectations.",
        "The surgeon's work is competent and reliable.",
        "The surgeon meets professional requirements.",
        "The surgeon's performance is up to standard.",
        "The surgeon has demonstrated adequate skills.",
        "The surgeon's work is reliable and meets expectations.",
        "The surgeon performs satisfactorily in most cases.",
        "The surgeon's work is generally adequate.",
        "The surgeon meets basic professional standards.",
        "The surgeon's performance is consistent with expectations.",
        "The surgeon has shown sufficient professional competence.",
        "The surgeon's work is adequate and meets standards.",
        "The surgeon performs to a satisfactory level.",
        "The surgeon meets the expected level of competence.",
        "The surgeon's work is generally acceptable.",
        "The surgeon has performed to a competent standard.",
        "The surgeon meets the necessary professional criteria."],
    4: ["I recommend this surgeon. They have consistently shown good skills and a professional demeanor.",
        "The surgeon has demonstrated excellent skills and professionalism.",
        "This surgeon is a reliable and competent professional.",
        "I am confident in recommending this surgeon for any position.",
        "The surgeon's work is of high quality and consistently reliable.",
        "This surgeon has shown great dedication and skill.",
        "I have no hesitation in recommending this surgeon.",
        "The surgeon's performance has been exemplary.",
        "This surgeon is a valuable asset to any medical team.",
        "The surgeon has consistently delivered excellent results.",
        "I highly recommend this surgeon for their skills and professionalism.",
        "The surgeon's work is outstanding and reliable.",
        "This surgeon is highly competent and professional.",
        "The surgeon has shown exceptional abilities and dedication.",
        "I strongly recommend this surgeon for their excellent work.",
        "The surgeon's performance has been consistently high.",
        "This surgeon is an excellent professional.",
        "I have full confidence in recommending this surgeon.",
        "The surgeon's work is consistently of high quality.",
        "This surgeon is a top-notch professional.",
        "I highly endorse this surgeon for their skills and dedication.",
        "The surgeon has demonstrated exceptional professional standards.",
        "This surgeon is highly reliable and competent.",
        "I strongly endorse this surgeon for any advanced role.",
        "The surgeon's performance has been consistently exemplary.",
        "This surgeon is a highly valuable member of any medical team.",
        "I have great confidence in recommending this surgeon.",
        "The surgeon's work is of consistently high quality.",
        "This surgeon is an outstanding professional.",
        "I highly recommend this surgeon for their exceptional skills."],
    5: ["This surgeon is outstanding. Their surgical skills and dedication to patient care are exemplary.",
        "I highly recommend this surgeon for their exceptional skills and professionalism.",
        "The surgeon has demonstrated extraordinary abilities and dedication.",
        "I have no reservations in recommending this surgeon for any position.",
        "This surgeon is an exceptional professional with outstanding skills.",
        "The surgeon's performance is unparalleled.",
        "I strongly recommend this surgeon for any high-level position.",
        "This surgeon is among the best I have worked with.",
        "The surgeon has shown remarkable skills and dedication.",
        "I highly endorse this surgeon for their extraordinary work.",
        "The surgeon's work is exceptional in every respect.",
        "This surgeon is a top-tier professional with outstanding abilities.",
        "I have the highest regard for this surgeon's skills and professionalism.",
        "The surgeon has consistently delivered extraordinary results.",
        "I strongly endorse this surgeon for any advanced role.",
        "The surgeon's work is of the highest quality.",
        "This surgeon is a truly exceptional professional.",
        "I highly recommend this surgeon for their exemplary work.",
        "The surgeon's performance is exceptional and reliable.",
        "This surgeon is an outstanding member of any medical team.",
        "I strongly recommend this surgeon for their exceptional skills.",
        "The surgeon's work is consistently outstanding.",
        "This surgeon is highly skilled and professional.",
        "I have no hesitation in recommending this surgeon.",
        "The surgeon's performance is consistently excellent.",
        "This surgeon is a highly valuable asset to any team.",
        "I have the utmost confidence in recommending this surgeon.",
        "The surgeon's work is exceptional and reliable.",
        "This surgeon is among the top professionals in their field.",
        "I highly recommend this surgeon for their outstanding abilities."]
}

# %%
recommendations_from_employers_samples = {
    1: ["This surgeon's tenure was fraught with issues. I would advise against hiring them.",
        "There were several performance and behavior concerns. Hiring this surgeon may not be advisable.",
        "This surgeon had multiple issues during their tenure.",
        "There were significant concerns regarding this surgeon's performance.",
        "This surgeon's professional conduct was highly problematic.",
        "Numerous complaints were received about this surgeon.",
        "This surgeon did not meet our professional standards.",
        "This surgeon's work was consistently below expectations.",
        "This surgeon demonstrated a lack of necessary skills.",
        "This surgeon's behavior and performance were unacceptable.",
        "This surgeon made several critical errors.",
        "This surgeon failed to meet our performance criteria.",
        "This surgeon's tenure was marked by numerous issues.",
        "This surgeon's work was frequently problematic.",
        "This surgeon's conduct was unprofessional.",
        "This surgeon's performance was consistently poor.",
        "This surgeon's tenure was highly unsatisfactory.",
        "This surgeon exhibited a lack of professionalism.",
        "This surgeon's behavior was concerning.",
        "This surgeon's work quality was substandard.",
        "This surgeon was frequently unreliable.",
        "This surgeon's skills were inadequate.",
        "This surgeon was often unprofessional.",
        "This surgeon did not perform to our standards.",
        "This surgeon's work was often below par.",
        "This surgeon's conduct was often problematic.",
        "This surgeon frequently failed to meet expectations.",
        "This surgeon's performance was disappointing.",
        "This surgeon was not a good fit for our team.",
        "This surgeon's work was consistently inadequate."],
    2: ["There were some performance concerns regarding this surgeon. Proceed with caution.",
        "This surgeon had several issues during their employment.",
        "There were occasional problems with this surgeon's work.",
        "This surgeon's performance was inconsistent.",
        "There were some concerns about this surgeon's professionalism.",
        "This surgeon had mixed reviews from colleagues.",
        "This surgeon's work was sometimes problematic.",
        "There were occasional complaints about this surgeon.",
        "This surgeon had some professional conduct issues.",
        "This surgeon's performance was occasionally below standard.",
        "There were some issues with this surgeon's work quality.",
        "This surgeon's reliability was sometimes questionable.",
        "There were minor concerns about this surgeon's behavior.",
        "This surgeon's performance had highs and lows.",
        "There were some negative reviews about this surgeon.",
        "This surgeon's conduct was occasionally problematic.",
        "There were a few complaints about this surgeon's professionalism.",
        "This surgeon's work was not consistently up to standard.",
        "There were some reservations about this surgeon's skills.",
        "This surgeon's behavior was sometimes concerning.",
        "There were occasional lapses in this surgeon's performance.",
        "This surgeon's work had some issues.",
        "There were some inconsistencies in this surgeon's performance.",
        "This surgeon's professional conduct had some issues.",
        "There were a few concerns about this surgeon's reliability.",
        "This surgeon's skills were sometimes lacking.",
        "There were minor issues with this surgeon's behavior.",
        "This surgeon's work quality varied.",
        "There were occasional problems with this surgeon's reliability.",
        "This surgeon's performance was not always satisfactory."],
    3: ["This surgeon has performed adequately. There are no major concerns, but also no standout qualities.",
        "The surgeon's work has been satisfactory and meets basic standards.",
        "The surgeon has performed at an acceptable level.",
        "There are no significant issues with this surgeon's performance.",
        "The surgeon's work is competent but unremarkable.",
        "The surgeon meets the necessary requirements.",
        "The surgeon's performance is average and meets expectations.",
        "The surgeon has shown satisfactory skills.",
        "The surgeon's work is sufficient and meets basic standards.",
        "The surgeon performs adequately under normal conditions.",
        "The surgeon's work is generally satisfactory.",
        "The surgeon meets the expected professional standards.",
        "The surgeon's performance is acceptable.",
        "The surgeon has consistently met basic expectations.",
        "The surgeon's work is competent and reliable.",
        "The surgeon meets professional requirements.",
        "The surgeon's performance is up to standard.",
        "The surgeon has demonstrated adequate skills.",
        "The surgeon's work is reliable and meets expectations.",
        "The surgeon performs satisfactorily in most cases.",
        "The surgeon's work is generally adequate.",
        "The surgeon meets basic professional standards.",
        "The surgeon's performance is consistent with expectations.",
        "The surgeon has shown sufficient professional competence.",
        "The surgeon's work is adequate and meets standards.",
        "The surgeon performs to a satisfactory level.",
        "The surgeon meets the expected level of competence.",
        "The surgeon's work is generally acceptable.",
        "The surgeon has performed to a competent standard.",
        "The surgeon meets the necessary professional criteria."],
    4: ["I recommend this surgeon. They have consistently shown good skills and a professional demeanor.",
        "The surgeon has demonstrated excellent skills and professionalism.",
        "This surgeon is a reliable and competent professional.",
        "I am confident in recommending this surgeon for any position.",
        "The surgeon's work is of high quality and consistently reliable.",
        "This surgeon has shown great dedication and skill.",
        "I have no hesitation in recommending this surgeon.",
        "The surgeon's performance has been exemplary.",
        "This surgeon is a valuable asset to any medical team.",
        "The surgeon has consistently delivered excellent results.",
        "I highly recommend this surgeon for their skills and professionalism.",
        "The surgeon's work is outstanding and reliable.",
        "This surgeon is highly competent and professional.",
        "The surgeon has shown exceptional abilities and dedication.",
        "I strongly recommend this surgeon for their excellent work.",
        "The surgeon's performance has been consistently high.",
        "This surgeon is an excellent professional.",
        "I have full confidence in recommending this surgeon.",
        "The surgeon's work is consistently of high quality.",
        "This surgeon is a top-notch professional.",
        "I highly endorse this surgeon for their skills and dedication.",
        "The surgeon has demonstrated exceptional professional standards.",
        "This surgeon is highly reliable and competent.",
        "I strongly endorse this surgeon for any advanced role.",
        "The surgeon's performance has been consistently exemplary.",
        "This surgeon is a highly valuable member of any medical team.",
        "I have great confidence in recommending this surgeon.",
        "The surgeon's work is of consistently high quality.",
        "This surgeon is an outstanding professional.",
        "I highly recommend this surgeon for their exceptional skills."],
    5: ["This surgeon is outstanding. Their surgical skills and dedication to patient care are exemplary.",
        "I highly recommend this surgeon for their exceptional skills and professionalism.",
        "The surgeon has demonstrated extraordinary abilities and dedication.",
        "I have no reservations in recommending this surgeon for any position.",
        "This surgeon is an exceptional professional with outstanding skills.",
        "The surgeon's performance is unparalleled.",
        "I strongly recommend this surgeon for any high-level position.",
        "This surgeon is among the best I have worked with.",
        "The surgeon has shown remarkable skills and dedication.",
        "I highly endorse this surgeon for their extraordinary work.",
        "The surgeon's work is exceptional in every respect.",
        "This surgeon is a top-tier professional with outstanding abilities.",
        "I have the highest regard for this surgeon's skills and professionalism.",
        "The surgeon has consistently delivered extraordinary results.",
        "I strongly endorse this surgeon for any advanced role.",
        "The surgeon's work is of the highest quality.",
        "This surgeon is a truly exceptional professional.",
        "I highly recommend this surgeon for their exemplary work.",
        "The surgeon's performance is exceptional and reliable.",
        "This surgeon is an outstanding member of any medical team.",
        "I strongly recommend this surgeon for their exceptional skills.",
        "The surgeon's work is consistently outstanding.",
        "This surgeon is highly skilled and professional.",
        "I have no hesitation in recommending this surgeon.",
        "The surgeon's performance is consistently excellent.",
        "This surgeon is a highly valuable asset to any team.",
        "I have the utmost confidence in recommending this surgeon.",
        "The surgeon's work is exceptional and reliable.",
        "This surgeon is among the top professionals in their field.",
        "I highly recommend this surgeon for their outstanding abilities."]
}

# %%
insurance_history_samples = {
    1: ["Insured with multiple claims and unresolved issues. High risk.",
        "Coverage with several claims filed, unresolved issues present.",
        "High-risk history with numerous claims.",
        "Multiple claims and poor resolution history.",
        "Insurance history marked by unresolved claims.",
        "Frequent claims and high risk associated.",
        "Multiple unresolved issues with insurance claims.",
        "Claims history indicates high risk.",
        "Numerous claims and ongoing issues.",
        "High number of claims filed and unresolved.",
        "Insurance record with many claims and poor resolution.",
        "Significant number of unresolved claims.",
        "Insurance history shows frequent claims and risks.",
        "History of multiple claims, unresolved issues remain.",
        "High-risk insurance profile with many claims.",
        "Numerous insurance claims and poor outcomes.",
        "Multiple unresolved claims on record.",
        "Insurance history filled with claims and issues.",
        "High number of claims, unresolved matters persist.",
        "Frequent issues with insurance claims.",
        "Insurance profile indicates multiple claims.",
        "Ongoing issues with numerous claims filed.",
        "Insurance history marked by frequent claims.",
        "Many claims filed, unresolved issues noted.",
        "High-risk profile with numerous insurance claims.",
        "Claims history shows multiple unresolved issues.",
        "Insurance record indicates high risk.",
        "Frequent claims and ongoing unresolved issues.",
        "Insurance profile marked by numerous claims.",
        "Significant unresolved issues with multiple claims."],
    2: ["Coverage with several claims filed. Risk level is above average.",
        "Insurance history with multiple claims, moderate risk.",
        "Several claims filed, some unresolved issues.",
        "Claims history indicates above average risk.",
        "Insurance profile with multiple claims filed.",
        "Moderate risk with several claims on record.",
        "Several claims, some issues remain unresolved.",
        "Insurance history shows moderate risk.",
        "Claims filed indicate above average risk.",
        "Multiple claims filed, risk level moderate.",
        "Insurance record with several claims, some unresolved.",
        "Claims history marked by above average risk.",
        "Moderate risk with multiple claims noted.",
        "Several claims on record, some issues persist.",
        "Insurance profile shows moderate risk level.",
        "Multiple claims filed, some unresolved matters.",
        "Insurance history indicates moderate risk.",
        "Claims record with several unresolved issues.",
        "Above average risk with multiple claims filed.",
        "Insurance profile with moderate risk noted.",
        "Several claims filed, some issues present.",
        "Insurance history with moderate risk level.",
        "Claims record indicates multiple issues.",
        "Several claims on record, risk level moderate.",
        "Insurance profile shows several claims filed.",
        "Moderate risk with unresolved claims noted.",
        "Claims history marked by multiple issues.",
        "Insurance record with moderate risk profile.",
        "Several claims filed, some issues unresolved.",
        "Insurance profile indicates moderate risk."],
    3: ["Standard insurance history with a few minor claims. Average risk.",
        "Insurance profile with a few claims, average risk level.",
        "A few minor claims filed, average risk noted.",
        "Claims history indicates average risk.",
        "Insurance record with a few minor claims.",
        "Average risk profile with minor claims filed.",
        "A few claims, risk level average.",
        "Insurance history shows average risk level.",
        "Claims record indicates minor issues, average risk.",
        "A few minor claims, insurance profile average.",
        "Insurance history with average risk profile.",
        "A few minor claims noted, risk level average.",
        "Claims record shows average risk.",
        "Average risk with a few minor claims.",
        "Insurance profile indicates average risk.",
        "A few minor claims, average risk noted.",
        "Claims history shows minor issues, average risk.",
        "Insurance record with average risk level.",
        "Minor claims filed, average risk profile.",
        "Average risk profile with a few claims.",
        "Insurance history marked by a few claims, average risk.",
        "Claims record indicates average risk level.",
        "A few minor claims, average risk profile.",
        "Insurance profile shows a few claims filed.",
        "Average risk with minor claims noted.",
        "Claims history marked by average risk.",
        "Insurance record indicates minor issues, average risk.",
        "A few claims filed, average risk profile.",
        "Average risk profile with minor issues.",
        "Insurance history indicates average risk."],
    4: ["Insured for many years with minimal claims. Low risk.",
        "Long-term insurance coverage with few claims, low risk.",
        "Minimal claims filed, low risk profile.",
        "Insurance history with minimal claims, low risk.",
        "Low-risk profile with few claims filed.",
        "Insurance record shows minimal claims, low risk.",
        "Few claims noted, insurance profile low risk.",
        "Low risk with minimal claims on record.",
        "Insurance history marked by minimal claims.",
        "Few claims filed, low-risk profile.",
        "Insurance profile with minimal claims, low risk.",
        "Minimal claims noted, low risk profile.",
        "Insurance record indicates low risk.",
        "Low risk with long-term insurance coverage.",
        "Minimal claims, low risk noted.",
        "Insurance history shows few claims, low risk.",
        "Low-risk profile with minimal claims filed.",
        "Insurance record marked by minimal claims.",
        "Few claims, insurance profile low risk.",
        "Low risk with minimal claims noted.",
        "Insurance history with low-risk profile.",
        "Minimal claims filed, low risk noted.",
        "Low risk profile with few claims.",
        "Insurance record indicates minimal claims, low risk.",
        "Few claims filed, low-risk profile noted.",
        "Insurance profile with low risk level.",
        "Minimal claims noted, low risk indicated.",
        "Low risk profile with minimal claims history.",
        "Insurance history marked by low risk.",
        "Few claims, low-risk profile noted."],
    5: ["Long-term coverage with no claims. Excellent standing and minimal risk.",
        "Insurance history with no claims, excellent standing.",
        "No claims filed, insurance profile excellent.",
        "Excellent standing with no claims on record.",
        "Insurance profile indicates excellent standing, no claims.",
        "No claims, excellent standing noted.",
        "Insurance history marked by excellent standing, no claims.",
        "Excellent insurance profile with no claims.",
        "No claims filed, excellent insurance history.",
        "Excellent standing with long-term coverage, no claims.",
        "Insurance record shows no claims, excellent standing.",
        "No claims, insurance profile excellent standing.",
        "Insurance history indicates excellent standing, no claims.",
        "Excellent profile with no claims filed.",
        "No claims on record, excellent standing.",
        "Insurance history marked by no claims, excellent standing.",
        "Excellent standing, no claims noted.",
        "No claims filed, excellent insurance profile.",
        "Insurance record indicates excellent standing, no claims.",
        "Excellent insurance history with no claims.",
        "No claims filed, excellent standing noted.",
        "Insurance profile with no claims, excellent standing.",
        "Excellent standing, no claims on record.",
        "No claims, excellent insurance history noted.",
        "Insurance record shows excellent standing, no claims.",
        "Excellent profile with long-term coverage, no claims.",
        "No claims filed, excellent standing indicated.",
        "Insurance history with excellent standing, no claims.",
        "Excellent standing, no claims history.",
        "No claims noted, insurance profile excellent."]
}

# %%
# Generate 1000 samples for each column based on defined ranges and labels
def generate_samples_with_labels():
    fdb_rating = random.randint(1,5)
    patient_feedback = random.choice(patient_feedback_samples[fdb_rating])
    rl_rating = random.randint(1,5)
    recommendation_letters = random.choice(recommendation_letters_samples[rl_rating])
    rfe_rating = random.randint(1,5)
    recommendations_from_employers = random.choice(recommendations_from_employers_samples[rfe_rating])
    ih_rating = random.randint(1,5)
    insurance_history = random.choice(insurance_history_samples[ih_rating])
    return patient_feedback, fdb_rating, recommendation_letters, rl_rating, recommendations_from_employers, rfe_rating, insurance_history, ih_rating

# %%
pip install faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker

fake = Faker()

surgical_courses = [
    "Anatomy",
    "Physiology",
    "Pathology",
    "Surgical Techniques",
    "Biochemistry",
    "Pharmacology",
    "Microbiology",
    "Ethics in Medical Practice",
    "Anesthesiology",
    "Emergency Medicine",
    "Robotic Surgery",
    "Trauma Surgery",
    "Pediatric Surgery",
    "Cardiothoracic Surgery",
    "Neurosurgery",
    "Orthopedic Surgery",
    "Plastic and Reconstructive Surgery",
    "Oncological Surgery",
    "Transplant Surgery",
    "Vascular Surgery"
]

# Helper function to generate random dates
def random_date(start, end):
    return fake.date_between(start_date=start, end_date=end)

# Generate sample data
data = []

for _ in range(1000):  # Assuming 100 doctors
    degree = random.choice(['MD', 'MBBS'])
    diploma_certification = random.choice([True, False])
    study_start_date = random_date('-30y', '-20y')
    study_end_date = random_date(study_start_date, '-15y')
    patient_feedback, fdb_rating, recommendation_letters, rl_rating, recommendations_from_employers, rfe_rating, insurance_history, ih_rating = generate_samples_with_labels()
    countries_nationality = ["Russia", "Ukraine", "Belarus", "Romania", "Poland", "France", "Germany", "United States", "Canada",
                         "Argentina", "Brazil", "United Kingdom", "South Africa", "Ethiopia", "India", "Philippines",
                         "Hungary", "Lithuania", "Moldova", "Uzbekistan"]
    probabilities_nationality = [0.15, 0.12, 0.05, 0.05, 0.05, 0.1, 0.05, 0.05, 0.05, 0.03, 0.03, 0.05, 0.03, 0.06, 0.05, 0.03, 0.03, 0.02, 0.02, 0.02]
    probabilities_nationality = np.array(probabilities_nationality) / np.sum(probabilities_nationality)
    nationality = np.random.choice(countries_nationality, p=probabilities_nationality)

    countries_education = ["Russia", "Ukraine", "Belarus", "Romania", "Poland", "France", "Germany", "United States", "Canada",
                       "Argentina", "Brazil", "United Kingdom", "South Africa", "Ethiopia", "India", "Philippines",
                       "Hungary", "Lithuania", "Moldova", "Uzbekistan"]
    probabilities_education = [0.1, 0.1, 0.04, 0.05, 0.04, 0.1, 0.06, 0.08, 0.06, 0.03, 0.03, 0.08, 0.03, 0.05, 0.05, 0.04, 0.03, 0.02, 0.03, 0.02]
    probabilities_education = np.array(probabilities_education) / np.sum(probabilities_education)

    education_country = np.random.choice(countries_education, p=probabilities_education)

    countries_location = ["Russia", "Ukraine", "Belarus", "Romania", "Poland", "France", "Germany", "United States", "Canada",
                      "Argentina", "Brazil", "United Kingdom", "South Africa", "Ethiopia", "India", "Philippines",
                      "Hungary", "Lithuania", "Moldova", "Uzbekistan"]
    probabilities_location = [0.12, 0.12, 0.05, 0.05, 0.04, 0.1, 0.05, 0.08, 0.05, 0.03, 0.03, 0.08, 0.04, 0.05, 0.05, 0.04, 0.03, 0.03, 0.03, 0.02]
    probabilities_location = np.array(probabilities_location) / np.sum(probabilities_location)

    location_country = np.random.choice(countries_location, p=probabilities_location)

    courses_grades = [(random.choice(surgical_courses), random.randint(50, 100), random_date(study_start_date, study_end_date), random_date(study_start_date, study_end_date)) for _ in range(10)]

    work_experience_years = random.randint(14, 40)
    workplaces = [{
        'Institution Name': fake.company(),
        'Location': location_country,
        'Type of Institution': random.choice(['Public', 'Private']),
        'Number of Years Worked There': random.randint(1, 30),
        'Medical Center Level': random.choice(['Primary', 'Secondary', 'Tertiary']),
        'Number of Surgeries Performed': random.randint(0, 1000),
        'Additional Responsibilities': [fake.job() for _ in range(random.randint(0, 5))],
        'Percentage of Patients with Complications': random.uniform(0, 100),
        'Patient Feedback': patient_feedback, #
        'Patient Feedback Label': fdb_rating,
        'Recommendation Letters': recommendation_letters, #
        'Recommendation Letters Label': rl_rating,
        'Recommendations from Former Employers': recommendations_from_employers,
        'Recommendations from Former Employers Label': rfe_rating#
    } for _ in range(random.randint(1, 5))]

    data.append({
        'Name': fake.name(),
        'Age': random.randint(35, 70),
        'Gender': random.choice(['Male', 'Female', 'Other']),
        'Nationality': nationality,
        'Contact Information': fake.phone_number(),
        'Education Country': education_country,
        'Degree': degree,
        'Diploma Certification': diploma_certification,
        'Study Start Date': study_start_date,
        'Study End Date': study_end_date,
        'Courses and Grades': courses_grades,
        'Certificate of Good Conduct': random.choice([True, False]),
        'Criminal Record in Israel': random.choice([True, False]),
        'specialty': random.choice(['General Surgery', 'Cardiac Surgery', 'Neurosurgery', 'Orthopedic Surgery', 'Pediatric Surgery', 'Plastic Surgery']),
        'Total Years of Experience': work_experience_years,
        'Workplaces': workplaces,
        'Medical Malpractice Claims': random.randint(0, 10),
        'Insurance History': insurance_history, #
        'Insurance History Label': ih_rating,
        'Proficiency in Hebrew': random.choice(['Beginner', 'Intermediate', 'Advanced', 'Fluent']),
        'Proficiency in English': random.choice(['Beginner', 'Intermediate', 'Advanced', 'Fluent']),
        'Number of Articles': np.random.poisson(1),
        'Academic Institution Name': fake.company(),
        'Israeli Medical Licensing Exam Results': random.uniform(0, 100),
        'Certification Date': random_date('-5y', 'today'),
        'recommendation': recommendation_letters,
        'patient_feedback': patient_feedback,
        'employer_recommendations': recommendations_from_employers
    })

# Convert to DataFrame for better visualization
df = pd.DataFrame(data)

#import ace_tools as tools; tools.display_dataframe_to_user(name="Doctors Experience Data", dataframe=df)

# %%
df
# Out:
#                    Name  Age  Gender     Nationality    Contact Information  \
# 0          Ryan Bradley   56  Female     Philippines   +1-404-355-6663x0694
# 1          Lisa Leonard   60   Other         Hungary      717.979.8309x9629
# 2     Jeremiah Marshall   66  Female       Argentina     (748)207-8149x9537
# 3              Amy Pope   63    Male           India       383-469-3633x913
# 4        Samuel Harding   53    Male  United Kingdom      254-272-8941x0376
# ..                  ...  ...     ...             ...                    ...
# 995       Julie Hammond   57  Female          France           647-676-6735
# 996      Jennifer Lewis   36   Other          Canada             6968690160
# 997  Jennifer Stevenson   67   Other     Philippines   001-840-204-4579x054
# 998   Christopher Moran   48    Male     Philippines  +1-606-859-9752x90654
# 999      Victoria Ellis   59  Female        Ethiopia       372-322-8082x561
#
# ...

# %%
import numpy as np

def calculate_total_surgeries(row):
    return sum(workplace['Number of Surgeries Performed'] for workplace in row['Workplaces'])

df['Total_Number of Surgeries Performed'] = df.apply(calculate_total_surgeries, axis=1)

def calculate_avg(row, title):
    return sum(workplace[title] for workplace in row['Workplaces'])/len(row['Workplaces'])

def complex_acceptance_criteria(row):
    weight_experience = 0.2
    weight_surgeries = 0.15
    weight_malpractice = -0.3
    weight_language = 0.1
    weight_recommendations = 0.1
    weight_patient_feedback = 0.1
    weight_employer_recommendations = 0.1
    weight_insurance_history = 0.1
    weight_exam_results = 0.2

    experience_score = min(row['Total Years of Experience'] / 40, 1) * weight_experience
    surgery_score = min(row['Total_Number of Surgeries Performed'] / 1000, 1) * weight_surgeries
    malpractice_score = min(row['Medical Malpractice Claims'] / 10, 1) * weight_malpractice
    language_score = (['Beginner', 'Intermediate', 'Advanced', 'Fluent'].index(row['Proficiency in Hebrew']) / 3 +
                      ['Beginner', 'Intermediate', 'Advanced', 'Fluent'].index(row['Proficiency in English']) / 3) / 2 * weight_language

    recommendation_label = calculate_avg(row, 'Recommendation Letters Label')
    recommendation_score = (recommendation_label / 5) * weight_recommendations

    patient_feedback_label = calculate_avg(row, 'Patient Feedback Label')
    patient_feedback_score = (patient_feedback_label / 5) * weight_patient_feedback

    employer_recommendations_label = calculate_avg(row, 'Recommendations from Former Employers Label')
    employer_recommendations_score = (employer_recommendations_label / 5) * weight_employer_recommendations

    insurance_history_label = row['Insurance History Label']
    insurance_history_score = (insurance_history_label / 5) * weight_insurance_history

    exam_score = (row['Israeli Medical Licensing Exam Results'] / 100) * weight_exam_results

    total_score = (experience_score + surgery_score + malpractice_score + language_score +
                   recommendation_score + patient_feedback_score + employer_recommendations_score +
                   insurance_history_score + exam_score)
    return total_score

df['total_score'] = df.apply(complex_acceptance_criteria, axis=1)
df['Accepted'] = df['total_score'] > 0.6

# %%
df["total_score"].describe()
# Out:
# count    1000.000000
# mean        0.501323
# std         0.135726
# min         0.123208
# 25%         0.408839
# 50%         0.500302
# 75%         0.597273
# max         0.848533
# Name: total_score, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the histogram
plt.figure(figsize=(6, 4))
sns.histplot(df['total_score'], bins=20, kde=True)
plt.title('Histogram of Total Score')
plt.xlabel('Total Score')
plt.ylabel('Frequency')
plt.show()

# %%
df['experience_score'] = df['Total Years of Experience'].apply(lambda x: min(x / 40, 1))
df['surgery_score'] = df['Total_Number of Surgeries Performed'].apply(lambda x: min(x / 1000, 1))
df['malpractice_score'] = df['Medical Malpractice Claims'].apply(lambda x: min(x / 10, 1))

df['Hebrew_score'] = df['Proficiency in Hebrew'].apply(lambda x: ['Beginner', 'Intermediate', 'Advanced', 'Fluent'].index(x) / 3)
df['English_score'] = df['Proficiency in English'].apply(lambda x: ['Beginner', 'Intermediate', 'Advanced', 'Fluent'].index(x) / 3)

# Calculate insurance history score
df['insurance_history_score'] = df['Insurance History Label'] / 5

# Calculate exam score
df['exam_score'] = df['Israeli Medical Licensing Exam Results'] / 100

# %%
# def calculate_avg(row, title):
#     return sum(workplace[title] for workplace in row['Workplaces'])/len(row['Workplaces'])
import json

# Define the calculate_avg function
def calculate_avg(row, title):
    return sum(workplace[title] for workplace in row['Workplaces']) / len(row['Workplaces'])

# Calculate scores using the calculate_avg function
df['recommendation_label'] = df.apply(lambda row: calculate_avg(row, 'Recommendation Letters Label'), axis=1)
df['recommendation_score'] = df['recommendation_label'] / 5

df['patient_feedback_label'] = df.apply(lambda row: calculate_avg(row, 'Patient Feedback Label'), axis=1)
df['patient_feedback_score'] = df['patient_feedback_label'] / 5

df['employer_recommendations_label'] = df.apply(lambda row: calculate_avg(row, 'Recommendations from Former Employers Label'), axis=1)
df['employer_recommendations_score'] = df['employer_recommendations_label'] / 5

# %%
df['Avg_Grades'] = df['Courses and Grades'].apply(
    lambda x: sum(grade for _, grade, _, _ in x) / len(x)
)

# %%
df
# Out:
#                    Name  Age  Gender     Nationality    Contact Information  \
# 0          Ryan Bradley   56  Female     Philippines   +1-404-355-6663x0694
# 1          Lisa Leonard   60   Other         Hungary      717.979.8309x9629
# 2     Jeremiah Marshall   66  Female       Argentina     (748)207-8149x9537
# 3              Amy Pope   63    Male           India       383-469-3633x913
# 4        Samuel Harding   53    Male  United Kingdom      254-272-8941x0376
# ..                  ...  ...     ...             ...                    ...
# 995       Julie Hammond   57  Female          France           647-676-6735
# 996      Jennifer Lewis   36   Other          Canada             6968690160
# 997  Jennifer Stevenson   67   Other     Philippines   001-840-204-4579x054
# 998   Christopher Moran   48    Male     Philippines  +1-606-859-9752x90654
# 999      Victoria Ellis   59  Female        Ethiopia       372-322-8082x561
#
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Nationality', 'Contact Information',
#        'Education Country', 'Degree', 'Diploma Certification',
#        'Study Start Date', 'Study End Date', 'Courses and Grades',
#        'Certificate of Good Conduct', 'Criminal Record in Israel', 'specialty',
#        'Total Years of Experience', 'Workplaces', 'Medical Malpractice Claims',
#        'Insurance History', 'Insurance History Label', 'Proficiency in Hebrew',
#        'Proficiency in English', 'Number of Articles',
#        'Academic Institution Name', 'Israeli Medical Licensing Exam Results',
#        'Certification Date', 'Total_Number of Surgeries Performed',
#        'total_score', 'Accepted', 'experience_score', 'surgery_score',
#        'malpractice_score', 'Hebrew_score', 'English_score',
#        'insurance_history_score', 'exam_score', 'recommendation_label',
#        'recommendation_score', 'patient_feedback_label',
#        'patient_feedback_score', 'employer_recommendations_label',
# ...

# %%
df.to_csv('doctors_data.csv', index=False)
